# %% [markdown]
# <h1>EDA for Student Performance Dataset</h1>

# %% [markdown]
# <h2>Lifecycle of Machine Learning Project</h2>

# %% [markdown]
# 1. Understanding of problem Statement
# 2. Data Collection
# 3. Data checks for performance
# 4. Exploratory Data Analysis
# 5. Data Pre Processing
# 6. Model Training
# 7. Choose Best Model

# %% [markdown]
# <h3>1. Understanding of Problem Statment</h3>

# %% [markdown]
# This project understands how student's performance(test score) is getting affected by variables such as gender, ethnicity, parental level of education, lunch, test preparation course.

# %% [markdown]
# <h3>2. Data Collection</h3>

# %% [markdown]
# - Data Scorce - Kaggle Data set
# - The data consists of 8 columns and 1000 rows

# %% [markdown]
# <h4>2.1 Import Data and Required Packages</h4>

# %% [markdown]
# Import Required Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# Running cells with 'c:\Users\Tnluser\Desktop\DS Stats\E2E DS Propjects\1. First Projects\venv2\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\Tnluser\Desktop\DS Stats\E2E DS Propjects\1. First Projects\venv2 ipykernel --update-deps --force-reinstall'

# %% [markdown]
# Import Dataset

# %%
df = pd.read_csv(r"C:\Users\Tnluser\Desktop\DS Stats\E2E DS Propjects\1. First Projects\notebook\data\stud.csv")

# %% [markdown]
# Show top 5 Records

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Shape of Dataset

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# Dataset Information
#
# - gender -> sex of the student(male/female) - Categorical Variable(Nominal)
# - race_ethnicity -> ethnicity of the student(Group A,B,C,D) - Categorical Variable(Nominal)
# - parental_level_of_education -> till what level parents have studied (master, bachelor, high school) - Categorical Variable(Ordinal)
# - lunch -> having lunch before test(standard/free) - Categorical Variable(Nominal)
# - test_preparation_course -> course taken to prepare for test(completed/none/not completed) - Categorical variable(Ordinal)
# - math_score -> Target Variable (Discrete)
# - reading_score -> Target Variable (Discrete)
# - writing_score -> Target Variable (Discrete)

# %% [markdown]
# <h3>3. Performing Data Check</h3>
#
# - Check for missing values
# - Check Duplicates
# - check Datatypes
# - Check number of unique values in a column
# - Check statistics of data set
# - Check Various categories present in different categorical columns

# %% [markdown]
# <h4>3.1 Check for Missing Values</h4>

# %%
sns.heatmap(df.isna(),cmap = 'viridis',cbar=False,yticklabels=False)
plt.show()

# %% [markdown]
# There is no missing values in the dataset

# %% [markdown]
# <h4>3.2 Check for Duplicates</h4>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate entries in the dataset

# %% [markdown]
# <h4>3.3 Check for Datatypes</h4>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# <h4>3.4 Check for number of unique variable in each column</h4>

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %% [markdown]
# <h4>3.5 Check for Statistics of the Data</h4>

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# <h3>Insights</h3>
#
# - For the Numerical Column of the data set Mean is very close to each other, between 66-69
# - Standard Deviation is also close to each other, between (14.6 - 15.19)
# - Minimum is varies in all 3 columns, ranging from 0 in maths to 17 in reading
# - max score is same in all 3 columns, ie 100

# %% [markdown]
# <h4>3.7 Exploring Dataset</h4>

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Find Unique Values in all categorical columns
print("Categories in 'gender' column: ",end="")
print(df.gender.unique())
print("Categories in 'race_ethnicity' column: ",end="")
print(df.race_ethnicity.unique())
print("Categories in 'parental_level_of_education' column: ",end="")
print(df.parental_level_of_education.unique())
print("Categories in 'lunch' column: ",end="")
print(df.lunch.unique())
print("Categories in 'test_preparation_course' column: ",end="")
print(df.test_preparation_course.unique())
# Out:
# Categories in 'gender' column: ['female' 'male']
# Categories in 'race_ethnicity' column: ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in 'parental_level_of_education' column: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in 'lunch' column: ['standard' 'free/reduced']
# Categories in 'test_preparation_course' column: ['none' 'completed']

# %%
#define numerical and categorical features
numerical_feature = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']

#Print columns
print('We have {} numerical feature and features are : {}'.format(len(numerical_feature),numerical_feature))
print('\nWe have {} categorical feature and features are : {}'.format(len(categorical_feature),categorical_feature))
# Out:
# We have 3 numerical feature and features are : ['math_score', 'reading_score', 'writing_score']
#
# We have 5 categorical feature and features are : ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']

# %% [markdown]
# <h4>3.8 Adding New Columns in Dataset</h4>

# %%
df['total_score'] = df.math_score+df.reading_score+df.writing_score
df['average_score'] = df.total_score/3

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %% [markdown]
# <h3>4 Exploring Data(Data Visulisation)</h3>

# %% [markdown]
# <h4>4.1 Visualise average score distribution to make some conclusion</h4>
#
# - Histogram
# - Kernel Distribution Function

# %%
fig, axes = plt.subplots(1,2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data = df,x='average_score',bins = 30,kde = True, color='g')
plt.subplot(122)
sns.histplot(data = df,x='average_score',hue='gender',kde = True)
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data = df,x='total_score',bins = 30,kde = True, color='g')
plt.subplot(122)
sns.histplot(data = df,x='total_score',hue='gender',kde = True)
plt.show()

# %% [markdown]
# Insights : Female students tends to better than male students

# %%
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

df.hist(bins=30, figsize=(12, 8))
plt.show()

# %%
plt.subplots(1,3,figsize=(26,6))
plt.subplot(131)
sns.histplot(data=df,x = 'average_score',kde = True,hue ='lunch' )
plt.subplot(132)
sns.histplot(data=df[df['gender']=='female'],x = 'average_score',kde = True, hue='lunch')
plt.subplot(133)
sns.histplot(data=df[df['gender']=='male'],x = 'average_score',kde = True, hue='lunch')
plt.show()

# %% [markdown]
# Insights:
# - Students who get standart lunch tend to do much better in exams
# - Standart lunch help in exam be it male or female

# %%
plt.subplots(1,3,figsize=(26,6))
plt.subplot(131)
sns.histplot(data=df,x = 'average_score',kde = True,hue ='parental_level_of_education' )
plt.subplot(132)
sns.histplot(data=df[df['gender']=='female'],x = 'average_score',kde = True, hue='parental_level_of_education')
plt.subplot(133)
sns.histplot(data=df[df['gender']=='male'],x = 'average_score',kde = True, hue='parental_level_of_education')
plt.show()

# %% [markdown]
# Insights:
# - In general parents education does not help in students performace in examination

# %%
plt.subplots(1,3,figsize=(26,6))
plt.subplot(131)
sns.histplot(data=df,x = 'average_score',kde = True,hue ='race_ethnicity' )
plt.subplot(132)
sns.histplot(data=df[df['gender']=='female'],x = 'average_score',kde = True, hue='race_ethnicity')
plt.subplot(133)
sns.histplot(data=df[df['gender']=='male'],x = 'average_score',kde = True, hue='race_ethnicity')
plt.show()

# %% [markdown]
# Insights:
# Students from Group A and Group B tends to perform poor in exam

# %%
plt.subplots(1,3,figsize=(26,6))
plt.subplot(131)
sns.histplot(data=df,x = 'average_score',kde = True,hue ='test_preparation_course' )
plt.subplot(132)
sns.histplot(data=df[df['gender']=='female'],x = 'average_score',kde = True, hue='test_preparation_course')
plt.subplot(133)
sns.histplot(data=df[df['gender']=='male'],x = 'average_score',kde = True, hue='test_preparation_course')
plt.show()

# %% [markdown]
# Insights:
# Test Prep Course Completion does not have impact in students performance

# %% [markdown]
# <h4>4.2 Mamimum Score by students in all 3 exams</h4>

# %%
plt.figure(figsize = (20,10))
plt.subplot(131)
plt.title('Math Score')
sns.violinplot(y= 'math_score',data=df,color = 'r', linewidth=3)
plt.subplot(132)
plt.title('Reading Score')
sns.violinplot(y= 'reading_score',data=df,color = 'b', linewidth=3)
plt.subplot(133)
plt.title('Writing Score')
sns.violinplot(y= 'writing_score',data=df,color = 'g', linewidth=3)
plt.show()

# %% [markdown]
# Insights:
# - It is visible that in maths highest no of student scored between 50-70 and for reading and writing its 60-80

# %% [markdown]
# <h4>4.3 Multivariate Analysis Using Pie Plot</h4>

# %%
plt.rcParams['figure.figsize'] = (10,12)
for i,feature in enumerate(categorical_feature,start=1):
    plt.subplot(5,2,i)
    size = df[feature].value_counts()
    labels = df[feature].unique()
    plt.pie(size,labels= labels,autopct = '%0.2f%%')
    plt.title(feature, fontsize = 20)
    plt.axis('off')

plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# Insights:
# - There are more female students than male students
# - Group C and Group B constitute the majority of the student population 58.1%
# - Students who get standard lunch are more
# - Majority of the students have not completed the test preparation course

# %% [markdown]
# <h4>4.4 Feature Wise Visulisation</h4>

# %% [markdown]
# 4.4.1 Gender Feature
# - How is dritribution of gender?
# - Has gender have any impact on student performance

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
f,ax = plt.subplots(1,2,figsize = (20,10))
sns.countplot(x= df['gender'],data = df,palette = 'bright',ax=ax[0],saturation=0.95,order = df['gender'].value_counts().index)
for container in ax[0].containers:
    ax[0].bar_label(container,color = 'black',size=20)

plt.pie(x=df['gender'].value_counts(),labels=df['gender'].value_counts().index,explode= [0,0.1],autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# Insights: Gender has a fairly balanced data set with 51.8% of female students and 48.2% of male students

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
gender_group = df.groupby('gender')

# %%
plt.figure(figsize = (7,7))

X = ['Total Average','Math Average','Reading Average','Writing Average']
female_score = np.round([gender_group['average_score'].mean()[0],
                gender_group['math_score'].mean()[0],
                gender_group['reading_score'].mean()[0],
               gender_group['writing_score'].mean()[0]],decimals=2)
male_score = np.round([gender_group['average_score'].mean()[1],
                gender_group['math_score'].mean()[1],
                gender_group['reading_score'].mean()[1],
               gender_group['writing_score'].mean()[1]],decimals=2)

X_axis = np.arange(len(X))
plt.subplot(211)
plt.bar(X_axis, male_score, 0.4,label='M',color='orange',)
plt.xticks(X_axis, X)
plt.legend()
plt.ylabel("Marks")
for i in range(len(X)):
    plt.text(X_axis[i], male_score[i],str(male_score[i]), ha='center', va='top')

plt.subplot(212)
plt.bar(X_axis, female_score, 0.4,label='F')
for i in range(len(X)):
    plt.text(X_axis[i], female_score[i],str(female_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Total average v/s Math average marks of both the genders", fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# Insights:
# - Female students score better than male studens on average score, reading and writing
# - Male students score btter than female in math

# %% [markdown]
# 4.4.2 RACE/ETHINICITY FEATURE
# - How is dritribution of ehtnicity?
# - Has ethnicity have any impact on student performance

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
f,ax = plt.subplots(1,2,figsize = (20,10))
sns.countplot(x= df['race_ethnicity'],data = df,palette = 'bright',ax=ax[0],saturation=0.95,order =df['race_ethnicity'].value_counts().index )
for container in ax[0].containers:
    ax[0].bar_label(container,color = 'black',size=20)

plt.pie(x=df['race_ethnicity'].value_counts(),labels=df['race_ethnicity'].value_counts().index,shadow=True,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Insigths:
# - Majority of students belong to group C and D ethnicity
# - Minimum amount od students belong to Group A ethnicity

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
ethnicity_group = df.groupby('race_ethnicity')
plt.figure(figsize = (10,20))

X = ['Total Average','Math Average','Reading Average','Writing Average']
group_a_score = np.round([ethnicity_group['average_score'].mean()[0],
                ethnicity_group['math_score'].mean()[0],
                ethnicity_group['reading_score'].mean()[0],
               ethnicity_group['writing_score'].mean()[0]],decimals=2)
group_b_score = np.round([ethnicity_group['average_score'].mean()[1],
                ethnicity_group['math_score'].mean()[1],
                ethnicity_group['reading_score'].mean()[1],
               ethnicity_group['writing_score'].mean()[1]],decimals=2)
group_c_score = np.round([ethnicity_group['average_score'].mean()[2],
                ethnicity_group['math_score'].mean()[2],
                ethnicity_group['reading_score'].mean()[2],
               ethnicity_group['writing_score'].mean()[2]],decimals=2)
group_d_score = np.round([ethnicity_group['average_score'].mean()[3],
                ethnicity_group['math_score'].mean()[3],
                ethnicity_group['reading_score'].mean()[3],
               ethnicity_group['writing_score'].mean()[3]],decimals=2)
group_e_score = np.round([ethnicity_group['average_score'].mean()[4],
                ethnicity_group['math_score'].mean()[4],
                ethnicity_group['reading_score'].mean()[4],
               ethnicity_group['writing_score'].mean()[4]],decimals=2)

X_axis = np.arange(len(X))
plt.subplot(511)
plt.bar(X_axis, group_a_score, 0.4,label='A',color='orange',)
plt.xticks(X_axis, X)
plt.legend()
plt.ylabel("Marks")
for i in range(len(X)):
    plt.text(X_axis[i], group_a_score[i],str(group_a_score[i]), ha='center', va='top')
plt.title("Average marks of different ethnicity", fontweight='bold')

plt.subplot(512)
plt.bar(X_axis, group_b_score, 0.4,label='B',color = 'red')
for i in range(len(X)):
    plt.text(X_axis[i], group_b_score[i],str(group_b_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different ethnicity", fontweight='bold')

plt.subplot(513)
plt.bar(X_axis, group_c_score, 0.4,label='C',color = 'blue')
for i in range(len(X)):
    plt.text(X_axis[i], group_c_score[i],str(group_c_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different ethnicity", fontweight='bold')

plt.subplot(514)
plt.bar(X_axis, group_d_score, 0.4,label='D',color = 'green')
for i in range(len(X)):
    plt.text(X_axis[i], group_d_score[i],str(group_d_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different ethnicity", fontweight='bold')

plt.subplot(515)
plt.bar(X_axis, group_e_score, 0.4,label='E',color = 'purple')
for i in range(len(X)):
    plt.text(X_axis[i], group_e_score[i],str(group_e_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different ethnicity", fontweight='bold')

plt.legend()
plt.show()

# %% [markdown]
# Insigths:
# - Group E have scored highest average marks
# - Group A have scored lowest average marks
# - Students from a lower socioeconomic status have a lower avg in all courses

# %% [markdown]
# 4.4.3 PARENTAL LEVEL OF EDUCATION FEATURE
#
# - What is educational background of student's parent ?
# -
# Is parental education has any impact on student's performance ?

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
f,ax = plt.subplots(1,2,figsize = (20,10))
sns.countplot(x= df['parental_level_of_education'],data = df,palette = 'bright',ax=ax[0],saturation=0.95,
              order =df['parental_level_of_education'].value_counts().index)
plt.xticks(rotation = 45)
for container in ax[0].containers:
    ax[0].bar_label(container,color = 'black',size=20)

plt.pie(x=df['parental_level_of_education'].value_counts(),labels=df['parental_level_of_education'].value_counts().index,shadow=True,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Insights:
# - Majority of students belongs to parents graduating from 'some college' & 'associate's degree'.

# %%
parent_loe_group = df.groupby('parental_level_of_education')
plt.figure(figsize = (10,20))

X = ['Total Average','Math Average','Reading Average','Writing Average']
AD_score = np.round([parent_loe_group['average_score'].mean()[0],
                parent_loe_group['math_score'].mean()[0],
                parent_loe_group['reading_score'].mean()[0],
               parent_loe_group['writing_score'].mean()[0]],decimals=2)
BD_score = np.round([parent_loe_group['average_score'].mean()[1],
                parent_loe_group['math_score'].mean()[1],
                parent_loe_group['reading_score'].mean()[1],
               parent_loe_group['writing_score'].mean()[1]],decimals=2)
HS_score = np.round([parent_loe_group['average_score'].mean()[2],
                parent_loe_group['math_score'].mean()[2],
                parent_loe_group['reading_score'].mean()[2],
               parent_loe_group['writing_score'].mean()[2]],decimals=2)
MD_score = np.round([parent_loe_group['average_score'].mean()[3],
                parent_loe_group['math_score'].mean()[3],
                parent_loe_group['reading_score'].mean()[3],
               parent_loe_group['writing_score'].mean()[3]],decimals=2)
SC_score = np.round([parent_loe_group['average_score'].mean()[4],
                parent_loe_group['math_score'].mean()[4],
                parent_loe_group['reading_score'].mean()[4],
               parent_loe_group['writing_score'].mean()[4]],decimals=2)
SHC_score = np.round([parent_loe_group['average_score'].mean()[5],
                parent_loe_group['math_score'].mean()[5],
                parent_loe_group['reading_score'].mean()[5],
               parent_loe_group['writing_score'].mean()[5]],decimals=2)

X_axis = np.arange(len(X))
plt.subplot(611)
plt.bar(X_axis, AD_score, 0.4,label="Associate Degree's",color='orange',)
plt.xticks(X_axis, X)
plt.legend()
plt.ylabel("Marks")
for i in range(len(X)):
    plt.text(X_axis[i], AD_score[i],str(AD_score[i]), ha='center', va='top')
plt.title("Average marks of different parental level of education", fontweight='bold')

plt.subplot(612)
plt.bar(X_axis, BD_score, 0.4,label="Bachelor's Degree",color = 'red')
for i in range(len(X)):
    plt.text(X_axis[i], BD_score[i],str(BD_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different parental level of education", fontweight='bold')

plt.subplot(613)
plt.bar(X_axis, HS_score, 0.4,label='High School',color = 'blue')
for i in range(len(X)):
    plt.text(X_axis[i], HS_score[i],str(HS_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different parental level of education", fontweight='bold')

plt.subplot(614)
plt.bar(X_axis, MD_score, 0.4,label="Master's Degree",color = 'green')
for i in range(len(X)):
    plt.text(X_axis[i], MD_score[i],str(MD_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different parental level of education", fontweight='bold')

plt.subplot(615)
plt.bar(X_axis, SC_score, 0.4,label='Some College',color = 'purple')
for i in range(len(X)):
    plt.text(X_axis[i], SC_score[i],str(SC_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different parental level of education", fontweight='bold')

plt.subplot(616)
plt.bar(X_axis, SHC_score, 0.4,label='Some High School',color = 'purple')
for i in range(len(X)):
    plt.text(X_axis[i], SHC_score[i],str(SHC_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Average marks of different parental level of education", fontweight='bold')

plt.legend()
plt.show()

# %% [markdown]
# Insights:
# - Students whose parents have studied till master's have scored higher than other

# %% [markdown]
# 4.4.4 LUNCH FEATURE
#
# - Which type of lunch is most common amoung students ?
# -
# What is the effect of lunch type on test results?

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
f,ax = plt.subplots(1,2,figsize = (20,10))
sns.countplot(x= df['lunch'],data = df,palette = 'bright',ax=ax[0],saturation=0.95,order = df['lunch'].value_counts().index)
for container in ax[0].containers:
    ax[0].bar_label(container,color = 'black',size=20)

plt.pie(x=df['lunch'].value_counts(),labels=df['lunch'].value_counts().index,explode= [0,0.1],autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# Insights:
#
# The majority of the students are served with standard lunch rather than free lunch

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
lunch_group = df.groupby('lunch')
plt.figure(figsize = (7,7))

X = ['Total Average','Math Average','Reading Average','Writing Average']
reduced_score = np.round([lunch_group['average_score'].mean()[0],
                lunch_group['math_score'].mean()[0],
                lunch_group['reading_score'].mean()[0],
               lunch_group['writing_score'].mean()[0]],decimals=2)
standard_score = np.round([lunch_group['average_score'].mean()[1],
                lunch_group['math_score'].mean()[1],
                lunch_group['reading_score'].mean()[1],
               lunch_group['writing_score'].mean()[1]],decimals=2)

X_axis = np.arange(len(X))
plt.subplot(211)
plt.bar(X_axis, reduced_score, 0.4,label='Free Lunch',color='orange',)
plt.xticks(X_axis, X)
plt.legend()
plt.ylabel("Marks")
for i in range(len(X)):
    plt.text(X_axis[i], reduced_score[i],str(reduced_score[i]), ha='center', va='top')

plt.subplot(212)
plt.bar(X_axis, standard_score, 0.4,label='Standard Lunch')
for i in range(len(X)):
    plt.text(X_axis[i], standard_score[i],str(standard_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Total average v/s Math average marks of lunch category", fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# Insights:
#
# - Students who are served with standard lunch score higher than student who are served with free lunch

# %% [markdown]
# 4.4.5 TEST PREP COURSE FEATURE
#
# - How many students have completed test prep course?
# -
# Is Test prepration course has any impact on student's performance ?

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
f,ax = plt.subplots(1,2,figsize = (20,10))
sns.countplot(x= df['test_preparation_course'],data = df,palette = 'bright',ax=ax[0],saturation=0.95,order = df['test_preparation_course'].value_counts().index)
for container in ax[0].containers:
    ax[0].bar_label(container,color = 'black',size=20)

plt.pie(x=df['test_preparation_course'].value_counts(),labels=df['test_preparation_course'].value_counts().index,explode= [0,0.1],autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# Insights:
# Majority of the students have not completed test prep course

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
test_group = df.groupby('test_preparation_course')
plt.figure(figsize = (7,7))

X = ['Total Average','Math Average','Reading Average','Writing Average']
completed_score = np.round([test_group['average_score'].mean()[0],
                test_group['math_score'].mean()[0],
                test_group['reading_score'].mean()[0],
               test_group['writing_score'].mean()[0]],decimals=2)
none_score = np.round([test_group['average_score'].mean()[1],
                test_group['math_score'].mean()[1],
                test_group['reading_score'].mean()[1],
               test_group['writing_score'].mean()[1]],decimals=2)

X_axis = np.arange(len(X))
plt.subplot(211)
plt.bar(X_axis, completed_score, 0.4,label='Completed',color='orange',)
plt.xticks(X_axis, X)
plt.legend()
plt.ylabel("Marks")
for i in range(len(X)):
    plt.text(X_axis[i], completed_score[i],str(completed_score[i]), ha='center', va='top')

plt.subplot(212)
plt.bar(X_axis, none_score, 0.4,label='Not Completed')
for i in range(len(X)):
    plt.text(X_axis[i], none_score[i],str(none_score[i]), ha='center', va='top')
plt.xticks(X_axis, X)
plt.ylabel("Marks")
plt.title("Total average v/s Math average marks Test Course Completion", fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# Insights:
#
# Student who have completed the course have scored higher than students who have not completed the course

# %% [markdown]
# <h4>4.5 Checking Outliers</h4>

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df.math_score,color = 'skyblue')
plt.subplot(142)
sns.boxplot(df.reading_score,color = 'hotpink')
plt.subplot(143)
sns.boxplot(df.writing_score,color = 'yellow')
plt.subplot(144)
sns.boxplot(df.average_score,color = 'lightgreen')
plt.show()

# %% [markdown]
# Insights:
# No Outliers Found

# %% [markdown]
# <h4>Multi Variate Analysis Using PairPlot</h4>

# %%
sns.pairplot(df,hue='gender')
plt.show()

# %% [markdown]
# Insights:
#
# If reading, math, writing score increases average score increases

# %% [markdown]
# <h4>5 CONCLUSION</h4>
#
# - Student's Performance is related with lunch, race, parental level education
# -
# Females lead in pass percentage and also are top-scorer
# -
# Student's Performance is not much related with test preparation cour
# - e
# Finishing preparation course is benefitial.
